# %%
import pandas as pd
df = pd.read_csv('Transactions_new.csv')
master_project = df['master_project_en']
unique_names = master_project.unique()
for name in unique_names:
    print(name)
# Out:
# nan
# Emirates Hills
# Jumeirah Islands
# Meadows 4
# Meadows 1
# Lakes - Hattan I
# Silicon Oasis
# Meadows 9
# Meadows 2
# Meadows 3
# Meadows 5
# Meadows 6
# Meadows 7
# Meadows 8
# Lakes - Hattan II
# Emaar's Street Of Dreams
# Arabian Ranches - Saheel
# Lakes - Hattan III
# Arabian Ranches - Golf Homes
# Al Barari
# Dubai Sports City
# Arabian Ranches - Mirador La Colccion 2
# Arabian Ranches - Mirador
# Arabian Ranches - Savannah
# Arabian Ranches - Terranova
# Arabian Ranches - Mirador La Colccion 1
# Arabian Ranches - Alvorada - 1
# Palm Jumeirah
# Arabian Ranches - Alvorada - 4
# Lakes - Maeen
# Sama Al Jadaf
# TECOM Site B
# The Villa
# Majan
# Business Bay
# Lakes - Deema 1
# Lakes - Deema 4
# Lakes - Deema 2
# Culture Village
# Jumeirah Village Circle
# Jumeirah Village Triangle
# TECOM Site C
# Jumeirah Golf
# Jumeirah Park
# Arabian Ranches - Polo Homes
# Dubai Health Care City Phase 1
# Dubiotech
# Jumeirah Lakes Towers
# Al Waha Villas
# Residential Complex
# ...
